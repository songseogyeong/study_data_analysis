# %% [markdown]
# ### RFM 분석 실습
# - Recency: 얼마나 최근에 구매했는가
# - Frequency: 얼마나 자주 구매했는가
# - Monetary: 얼마나 많은 금액을 지출했는가

# %% [markdown]
# ### 고객 분석
# - InvoiceNo: 거래 번호
# - StockCode: 상품 코드
# - Description: 상품명
# - InvoiceDate: 거래 날짜
# - UnitPrice: 상품 단가
# - CustomerID: 고객 번호
# - Country: 국가명

# %%
import pandas as pd

ci_df = pd.read_csv('./datasets/customer_invoice_data.csv')
ci_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
ci_df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ci_df = ci_df.drop(index=ci_df[ci_df['CustomerID'].isna()].index, axis=1)

# %%
import numpy as np

ci_df = ci_df.astype({'CustomerID': np.int16})
ci_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55       17850  United Kingdom
# 1        12/1/2010 8:26       3.39       17850  United Kingdom
# 2        12/1/2010 8:26       2.75       17850  United Kingdom
# 3        12/1/2010 8:26       3.39       17850  United Kingdom
# 4        12/1/2010 8:26       3.39       17850  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85       12680          France
# 541905  12/9/2011 12:50       2.10       12680          France
# 541906  12/9/2011 12:50       4.15       12680          France
# 541907  12/9/2011 12:50       4.15       12680          France
# 541908  12/9/2011 12:50       4.95       12680          France
#
# [406829 rows x 8 columns]

# %%
ci_df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
ci_df = ci_df.reset_index(drop=True)
ci_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406824    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 406825    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55       17850  United Kingdom
# 1        12/1/2010 8:26       3.39       17850  United Kingdom
# 2        12/1/2010 8:26       2.75       17850  United Kingdom
# 3        12/1/2010 8:26       3.39       17850  United Kingdom
# 4        12/1/2010 8:26       3.39       17850  United Kingdom
# ...                 ...        ...         ...             ...
# 406824  12/9/2011 12:50       0.85       12680          France
# 406825  12/9/2011 12:50       2.10       12680          France
# 406826  12/9/2011 12:50       4.15       12680          France
# 406827  12/9/2011 12:50       4.15       12680          France
# 406828  12/9/2011 12:50       4.95       12680          France
#
# [406829 rows x 8 columns]

# %%
ci_df.duplicated().sum()
# Out:
# 5225

# %%
ci_rf_df = ci_df[ci_df['Quantity'] >= 0]
ci_rf_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406824    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 406825    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55       17850  United Kingdom
# 1        12/1/2010 8:26       3.39       17850  United Kingdom
# 2        12/1/2010 8:26       2.75       17850  United Kingdom
# 3        12/1/2010 8:26       3.39       17850  United Kingdom
# 4        12/1/2010 8:26       3.39       17850  United Kingdom
# ...                 ...        ...         ...             ...
# 406824  12/9/2011 12:50       0.85       12680          France
# 406825  12/9/2011 12:50       2.10       12680          France
# 406826  12/9/2011 12:50       4.15       12680          France
# 406827  12/9/2011 12:50       4.15       12680          France
# 406828  12/9/2011 12:50       4.95       12680          France
#
# [397924 rows x 8 columns]

# %%
ci_rf_df.loc[:, 'Recency'] = pd.to_datetime(ci_df['InvoiceDate'])\
                    .apply(lambda x: (pd.to_datetime('2011-12-10') - x).days)
ci_rf_df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11964\2500457790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ci_rf_df.loc[:, 'Recency'] = pd.to_datetime(ci_df['InvoiceDate'])\
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406824    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 406825    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Recency
# 0        12/1/2010 8:26       2.55       17850  United Kingdom      373
# 1        12/1/2010 8:26       3.39       17850  United Kingdom      373
# 2        12/1/2010 8:26       2.75       17850  United Kingdom      373
# 3        12/1/2010 8:26       3.39       17850  United Kingdom      373
# 4        12/1/2010 8:26       3.39       17850  United Kingdom      373
# ...                 ...        ...         ...             ...      ...
# 406824  12/9/2011 12:50       0.85       12680          France        0
# 406825  12/9/2011 12:50       2.10       12680          France        0
# 406826  12/9/2011 12:50       4.15       12680          France        0
# 406827  12/9/2011 12:50       4.15       12680          France        0
# 406828  12/9/2011 12:50       4.95       12680          France        0
#
# [397924 rows x 9 columns]

# %%
ci_rf_df = ci_rf_df.drop(['InvoiceDate'], axis=1)

# %%
rf_df = ci_rf_df.groupby('CustomerID').agg(Recency=('Recency', 'min'), Frequency=('CustomerID', 'count'))
rf_df
# Out:
#             Recency  Frequency
# CustomerID
# 12346           325          1
# 12347             2        182
# 12348            75         31
# 12349            18         73
# 12350           310         17
# ...             ...        ...
# 18280           277         10
# 18281           180          7
# 18282             7         12
# 18283             3        756
# 18287            42         70
#
# [4339 rows x 2 columns]

# %%
m_df = ci_df.copy()
m_df.loc[:, 'Monetary'] = m_df['Quantity'] * m_df['UnitPrice']
m_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406824    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 406825    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Monetary
# 0        12/1/2010 8:26       2.55       17850  United Kingdom     15.30
# 1        12/1/2010 8:26       3.39       17850  United Kingdom     20.34
# 2        12/1/2010 8:26       2.75       17850  United Kingdom     22.00
# 3        12/1/2010 8:26       3.39       17850  United Kingdom     20.34
# 4        12/1/2010 8:26       3.39       17850  United Kingdom     20.34
# ...                 ...        ...         ...             ...       ...
# 406824  12/9/2011 12:50       0.85       12680          France     10.20
# 406825  12/9/2011 12:50       2.10       12680          France     12.60
# 406826  12/9/2011 12:50       4.15       12680          France     16.60
# 406827  12/9/2011 12:50       4.15       12680          France     16.60
# 406828  12/9/2011 12:50       4.95       12680          France     14.85
#
# [406829 rows x 9 columns]

# %%
m_df = m_df.groupby('CustomerID')[['Monetary']].sum()
m_df
# Out:
#             Monetary
# CustomerID
# 12346           0.00
# 12347        4310.00
# 12348        1797.24
# 12349        1757.55
# 12350         334.40
# ...              ...
# 18280         180.60
# 18281          80.82
# 18282         176.60
# 18283        2094.88
# 18287        1837.28
#
# [4372 rows x 1 columns]

# %%
rf_df = rf_df.reset_index()
rf_df
# Out:
#       CustomerID  Recency  Frequency
# 0          12346      325          1
# 1          12347        2        182
# 2          12348       75         31
# 3          12349       18         73
# 4          12350      310         17
# ...          ...      ...        ...
# 4334       18280      277         10
# 4335       18281      180          7
# 4336       18282        7         12
# 4337       18283        3        756
# 4338       18287       42         70
#
# [4339 rows x 3 columns]

# %%
m_df = m_df.reset_index()
m_df
# Out:
#       CustomerID  Monetary
# 0          12346      0.00
# 1          12347   4310.00
# 2          12348   1797.24
# 3          12349   1757.55
# 4          12350    334.40
# ...          ...       ...
# 4367       18280    180.60
# 4368       18281     80.82
# 4369       18282    176.60
# 4370       18283   2094.88
# 4371       18287   1837.28
#
# [4372 rows x 2 columns]

# %%
rfm_df = rf_df.merge(m_df, on='CustomerID')
rfm_df
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0          12346      325          1      0.00
# 1          12347        2        182   4310.00
# 2          12348       75         31   1797.24
# 3          12349       18         73   1757.55
# 4          12350      310         17    334.40
# ...          ...      ...        ...       ...
# 4334       18280      277         10    180.60
# 4335       18281      180          7     80.82
# 4336       18282        7         12    176.60
# 4337       18283        3        756   2094.88
# 4338       18287       42         70   1837.28
#
# [4339 rows x 4 columns]

# %%
rfm_df.iloc[rfm_df[rfm_df['Monetary'] < 0].index] = 0
rfm_df[rfm_df['Monetary'] < 0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Recency, Frequency, Monetary]
# Index: []

# %%
rfm_df
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0          12346      325          1      0.00
# 1          12347        2        182   4310.00
# 2          12348       75         31   1797.24
# 3          12349       18         73   1757.55
# 4          12350      310         17    334.40
# ...          ...      ...        ...       ...
# 4334       18280      277         10    180.60
# 4335       18281      180          7     80.82
# 4336       18282        7         12    176.60
# 4337       18283        3        756   2094.88
# 4338       18287       42         70   1837.28
#
# [4339 rows x 4 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

rfm_scale = MinMaxScaler()
rfm_scale = rfm_scale.fit_transform(rfm_df[['Recency', 'Frequency', 'Monetary']])

# %%
rfm_df[['Recency', 'Frequency', 'Monetary']] = pd.DataFrame(rfm_scale, columns=['Recency', 'Frequency', 'Monetary'])
rfm_df
# Out:
#       CustomerID   Recency  Frequency  Monetary
# 0          12346  0.871314   0.000127  0.000000
# 1          12347  0.005362   0.023194  0.015421
# 2          12348  0.201072   0.003951  0.006430
# 3          12349  0.048257   0.009303  0.006288
# 4          12350  0.831099   0.002166  0.001196
# ...          ...       ...        ...       ...
# 4334       18280  0.742627   0.001274  0.000646
# 4335       18281  0.482574   0.000892  0.000289
# 4336       18282  0.018767   0.001529  0.000632
# 4337       18283  0.008043   0.096343  0.007495
# 4338       18287  0.112601   0.008921  0.006574
#
# [4339 rows x 4 columns]

# %%
rfm_df['Recency'] = 1 - rfm_df['Recency']

# %%
rfm_df
# Out:
#       CustomerID   Recency  Frequency  Monetary
# 0          12346  0.128686   0.000127  0.000000
# 1          12347  0.994638   0.023194  0.015421
# 2          12348  0.798928   0.003951  0.006430
# 3          12349  0.951743   0.009303  0.006288
# 4          12350  0.168901   0.002166  0.001196
# ...          ...       ...        ...       ...
# 4334       18280  0.257373   0.001274  0.000646
# 4335       18281  0.517426   0.000892  0.000289
# 4336       18282  0.981233   0.001529  0.000632
# 4337       18283  0.991957   0.096343  0.007495
# 4338       18287  0.887399   0.008921  0.006574
#
# [4339 rows x 4 columns]

# %%
rfm_df.loc[:, 'TotalScore'] = rfm_df['Recency'] + rfm_df['Frequency'] + rfm_df['Monetary']
rfm_df
# Out:
#       CustomerID   Recency  Frequency  Monetary  TotalScore
# 0          12346  0.128686   0.000127  0.000000    0.128814
# 1          12347  0.994638   0.023194  0.015421    1.033253
# 2          12348  0.798928   0.003951  0.006430    0.809309
# 3          12349  0.951743   0.009303  0.006288    0.967334
# 4          12350  0.168901   0.002166  0.001196    0.172264
# ...          ...       ...        ...       ...         ...
# 4334       18280  0.257373   0.001274  0.000646    0.259293
# 4335       18281  0.517426   0.000892  0.000289    0.518608
# 4336       18282  0.981233   0.001529  0.000632    0.983394
# 4337       18283  0.991957   0.096343  0.007495    1.095795
# 4338       18287  0.887399   0.008921  0.006574    0.902894
#
# [4339 rows x 5 columns]

# %%
ci_rfm_df = ci_df.merge(rfm_df[['CustomerID', 'TotalScore']], on='CustomerID')
ci_rfm_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406592    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 406593    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 406594    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 406595    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 406596    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalScore
# 0        12/1/2010 8:26       2.55       17850  United Kingdom    0.059452
# 1        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# 2        12/1/2010 8:26       2.75       17850  United Kingdom    0.059452
# 3        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# 4        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# ...                 ...        ...         ...             ...         ...
# 406592  12/9/2011 12:16       1.25       12713         Germany    1.007879
# 406593  12/9/2011 12:16       0.85       12713         Germany    1.007879
# 406594  12/9/2011 12:16       0.85       12713         Germany    1.007879
# 406595  12/9/2011 12:16       2.08       12713         Germany    1.007879
# 406596  12/9/2011 12:16       1.65       12713         Germany    1.007879
#
# [406597 rows x 9 columns]

# %%
import numpy as np

l1, l2, l3, l4 = np.percentile(ci_rfm_df['TotalScore'], [20, 40, 70, 90])
print(l1, l2, l3, l4)
# Out:
# 0.869671483418675 0.9705318110522853 1.0420786444685686 1.2380770969461894

# %%
def get_level(x):
    if x <= l1:
        return 5
    if x <= l2:
        return 4
    if x <= l3:
        return 3
    if x <= l4:
        return 2
    return 1

# %%
ci_rfm_df['Level'] = ci_rfm_df['TotalScore'].apply(get_level)
ci_rfm_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 406592    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 406593    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 406594    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 406595    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 406596    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalScore  \
# 0        12/1/2010 8:26       2.55       17850  United Kingdom    0.059452
# 1        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# 2        12/1/2010 8:26       2.75       17850  United Kingdom    0.059452
# 3        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# 4        12/1/2010 8:26       3.39       17850  United Kingdom    0.059452
# ...                 ...        ...         ...             ...         ...
# 406592  12/9/2011 12:16       1.25       12713         Germany    1.007879
# 406593  12/9/2011 12:16       0.85       12713         Germany    1.007879
# 406594  12/9/2011 12:16       0.85       12713         Germany    1.007879
# 406595  12/9/2011 12:16       2.08       12713         Germany    1.007879
# 406596  12/9/2011 12:16       1.65       12713         Germany    1.007879
#
#         Level
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5
# ...       ...
# 406592      3
# 406593      3
# 406594      3
# 406595      3
# 406596      3
#
# [406597 rows x 10 columns]

# %%
ci_rfm_df['Level'] = ci_rfm_df['Level'].replace([5, 4, 3, 2, 1], 
                                                ['Bronze', 'Silver', 'Gold', 'Diamond', 'VIP'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

order = ['Bronze', 'Silver', 'Gold', 'Diamond', 'VIP']

sns.countplot(x = 'Level', data=ci_rfm_df, palette='muted', order=order)
plt.title('Level Count')
plt.show()
